# %% [markdown]
# # スライドショーの作成
#
# ## Jupyter Notebook ではこんな事もできますよ

# %% [markdown]
# んほおおおおおおおおおおおおおおおおお！！！しゅごいのおおおおおおおおおおお

# %%
import matplotlib.pyplot as plt


figure = plt.figure()
ax = figure.add_subplot(111)

ax.plot([1, 2, 3, 4])

plt.show()
